# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Primeiro codigo)")
# Out:
# Primeiro codigo)

# %% [markdown]
# # MEU PRIMEIRO PROGRAMA
#
# Nesse programa vamos aprender a base inicial de Python
